# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'].fillna(titanic['age'].mean(), inplace=True)

# %%
titanic['deck'].fillna(method='bfill',inplace=True)
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_3116\3613741684.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   titanic['deck'].fillna(method='bfill',inplace=True)

# %%
titanic[titanic['embarked'].isna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
titanic['embarked'].fillna(method='bfill', inplace=True)
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_3116\3174584622.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   titanic['embarked'].fillna(method='bfill', inplace=True)

# %%
titanic['embark_town'].fillna(method='bfill', inplace=True)
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_3116\410606737.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   titanic['embark_town'].fillna(method='bfill', inplace=True)

# %%
titanic.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           1
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic.duplicated().sum()
# Out:
# 47

# %%
titanic.drop_duplicates(inplace=True)

# %%
titanic.duplicated().sum()
# Out:
# 0

# %%
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           1
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.dropna(inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 885         0       3  female  39.000000      0      5  29.1250        Q
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Chick outliers in age

# %%
sns.boxplot(titanic['age'])
plt.grid()
plt.title('Age Fig')
# Out:
# Text(0.5, 1.0, 'Age Fig')

# %% [markdown]
# #### Delete outliers of age

# %%
sns.boxplot(titanic[titanic['age']<52]['age'])
plt.grid()
plt.title('Age Fig')
# Out:
# Text(0.5, 1.0, 'Age Fig')

# %% [markdown]
# #### Chick outliers in fare

# %%
plt.figure(figsize=(5,5))
sns.boxplot(titanic['fare'])
plt.grid()
plt.title('fare fig')
# Out:
# Text(0.5, 1.0, 'fare fig')

# %% [markdown]
# ### VIP Fare

# %%
# titanic[titanic['fare']>50].value_counts().sum()

# %%
titanic['vip_fare'] = titanic[titanic['fare'] > 100]['fare']
# titanic['vip_fare'].dropna(inplace=True)
# titanic['vip_fare']

# %%
titanic['vip_fare'].fillna(0,inplace=True)

# %%
round(titanic[titanic['vip_fare'] != 0],2)
# Out:
#      survived  pclass     sex    age  sibsp  parch    fare embarked  class  \
# 27          0       1    male  19.00      3      2  263.00        S  First
# 31          1       1  female  29.70      1      0  146.52        C  First
# 88          1       1  female  23.00      3      2  263.00        S  First
# 118         0       1    male  24.00      0      1  247.52        C  First
# 195         1       1  female  58.00      0      0  146.52        C  First
# 215         1       1  female  31.00      1      0  113.28        C  First
# 258         1       1  female  35.00      0      0  512.33        C  First
# 268         1       1  female  58.00      0      1  153.46        S  First
# 269         1       1  female  35.00      0      0  135.63        S  First
# 297         0       1  female   2.00      1      2  151.55        S  First
# 299         1       1  female  50.00      0      1  247.52        C  First
# ...

# %%
titanic[titanic['vip_fare']== titanic['vip_fare'].max()]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone  vip_fare
# 258  woman       False    E   Cherbourg   yes   True  512.3292
# 679    man        True    B   Cherbourg   yes  False  512.3292
# 737    man        True    B   Cherbourg   yes   True  512.3292
